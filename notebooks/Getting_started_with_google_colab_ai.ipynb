# %% [markdown]
# <a href="https://colab.research.google.com/github/SanFilm/GB_FinalControlWork_2304/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Пошаговая настройка в Google Colab

# %%
# 1. Клонируем репозиторий
# !git clone https://github.com/HeartMuLa/heartlib.git
# %cd heartlib

# 2. Устанавливаем зависимости
# !pip install -e .

# 3. Устанавливаем утилиту для скачивания моделей с Hugging Face
# !pip install -U huggingface_hub

# 4. Скачиваем веса моделей (требуется аккаунт Hugging Face)
from huggingface_hub import snapshot_download

# HeartMuLa 3B модель
snapshot_download(
    repo_id="HeartMuLa/HeartMuLa-oss-3B",
    local_dir="./ckpt/HeartMuLa-oss-3B"
)

# HeartCodec (аудио декодер)
snapshot_download(
    repo_id="HeartMuLa/HeartCodec-oss",
    local_dir="./ckpt/HeartCodec-oss"
)
# Out:
# fatal: destination path 'heartlib' already exists and is not an empty directory.
# /content/heartlib
# Obtaining file:///content/heartlib
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Using cached huggingface_hub-0.36.1-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached huggingface_hub-0.36.1-py3-none-any.whl (566 kB)
# ...
#   Building editable for heartlib (pyproject.toml) ... done
#   Created wheel for heartlib: filename=heartlib-0.1.0-0.editable-py3-none-any.whl size=9942 sha256=fdf7b904ab0388a6d74c4adfc93ae774837398db87c342f772232505a2652bbe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a2dwutih/wheels/f7/83/9a/76977e87e829307ac4b5a18f7f9632f002bae720ac6e8d1b22
# Successfully built heartlib
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.3.7
# ...

# %% [markdown]
# Генерация музыки

# %%
# Пример запуска генерации
# !python ./examples/run_music_generation.py \
  --model_path=./ckpt \
  --version="3B" \
  --lazy_load true  # обязательно для ограничения памяти
# Out:
# Traceback (most recent call last):
#   File "/content/heartlib/./examples/run_music_generation.py", line 1, in <module>
#     from heartlib import HeartMuLaGenPipeline
#   File "/content/heartlib/src/heartlib/__init__.py", line 1, in <module>
#     from .pipelines.music_generation import HeartMuLaGenPipeline
#   File "/content/heartlib/src/heartlib/pipelines/music_generation.py", line 2, in <module>
#     from ..heartmula.modeling_heartmula import HeartMuLa
#   File "/content/heartlib/src/heartlib/heartmula/modeling_heartmula.py", line 3, in <module>
#     from .configuration_heartmula import HeartMuLaConfig
#   File "/content/heartlib/src/heartlib/heartmula/configuration_heartmula.py", line 1, in <module>
#     from transformers.configuration_utils import PretrainedConfig
#   File "/usr/local/lib/python3.12/dist-packages/transformers/__init__.py", line 27, in <module>
#     from . import dependency_versions_check
# ...
